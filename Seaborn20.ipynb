# %%
# Seaborn
# Seaborn is a Python data visualization library based on matplotlib. It provides a high-level interface for drawing 
# attractive and informative statistical graphics.

# %%
pip install seaborn
# Out:
# Requirement already satisfied: seaborn in c:\users\harsh\anaconda3\lib\site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\harsh\anaconda3\lib\site-packages (from seaborn) (1.26.4)
# Requirement already satisfied: pandas>=1.2 in c:\users\harsh\anaconda3\lib\site-packages (from seaborn) (2.2.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\harsh\anaconda3\lib\site-packages (from seaborn) (3.9.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\harsh\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\harsh\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\harsh\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\harsh\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\harsh\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\harsh\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\harsh\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\harsh\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\harsh\anaconda3\lib\site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\harsh\anaconda3\lib\site-packages (from pandas>=1.2->seaborn) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\harsh\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Importing Seaborn
# to use seaborn import it along with matplotlib and pandas

# %%
# Importing Seaborn
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Loading Dataset
# Seaborn comes with built-in datasets that you can use for practise. Let's load the "tips" dataset

# %%
# Load the tips dataset

tips = sns.load_dataset("tips")
print(tips.head())
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.scatterplot(x = "total_bill", y = "tip", data = tips)
plt.title("total bill Vs tips")
plt.grid()
plt.show()

# %%
# Line plot
sns.lineplot(x = "total_bill", y = "tip", data = tips)
plt.title("total bill Vs tips")
plt.grid()
plt.show()

# %%
# Bar plot
sns.barplot(x = "day", y = "total_bill", data = tips)
plt.title("Bar plot day Vs total_bill")
plt.show()

# %%
sns.histplot(tips['total_bill'], kde = True)
plt.title("Histplot of totalbill")
plt.show()

# %%
# Box plot
# a box plot (also called box and whisker plot) is a graph that shows the spread and distribution of a dataset using 5 key summary values.

# %%
sns.boxplot(x = "day", y = "total_bill", data = tips)
plt.title("total bill by day(box plot)")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# Pair Plot
# A pairplot is a powerful visualization tool that shows pairwise relationships between multiple columns in a dataset — especially
# useful for exploring numerical data.

# A pairplot creates:

# Scatter plots between every pair of numerical columns

# Histograms (or KDEs) on the diagonal for individual columns

# %%
sns.pairplot(tips, hue = "sex")

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# Heatmap
# A heatmap is a data visualization technique that uses color to represent the magnitude of values in a matrix or 2D data.
# Or you can say a heatmap is like a colorful table — instead of just showing numbers, it uses colors to make patterns and trends easy to see.

# %%
# Heat map
# selected the numeric column
selected_columns = ['total_bill', 'tip', 'size']

corr = tips[selected_columns].corr()

# plot heatmap
sns.heatmap(corr, annot = True,  cmap = 'YlGnBu')
plt.title("correlation heatmap(Selected columns)")
plt.show()

# %%
# Violin Plot
# Violin Plot is a method to visualize the distribution of numerical data of different variables. It is quite similar to Box Plot but with
# a rotated plot on each side, giving more information about the density estimate on the y-axis.

# A violin plot consists of four components.

# A white Centered Dot at the middle of the graph - The white dot point at the middle is the median of the distribution.
# A thin gray bar inside the plot - The bar in the plot represents the Quartile range of the distribution.
# A long thin line coming outside from the bar - The thin line represents the rest of the distribution which is calculated by the formulae Q1-1.5
# IQR for the lower range and Q3+1.5 IQR for the upper range. The point lying beyond this line are considered as outliers.
# A line boundary separating the plot- A KDE plot is used for defining the boundary of the violin plot it represents the distribution of data points.

# %%
# Create a violin plot
sns.violinplot(x='day', y='tip', data=tips)

# Add title and show the plot
plt.title('Violin Plot of Tips by Day')
plt.show()

# %%
# What this shows:

# Distribution of tips for each day (Thu, Fri, Sat, Sun).

# The width of the violin indicates the density of data points at different values.
